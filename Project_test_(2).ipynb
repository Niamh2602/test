# %% [markdown]
# <a href="https://colab.research.google.com/github/Niamh2602/test/blob/main/Project_test_(2).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import io
import pandas as pd
import folium
import gc


data = files.upload()
# Out:
#      <input type="file" id="files-8619fdaa-8e78-456a-b7b8-e883d5a76848" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8619fdaa-8e78-456a-b7b8-e883d5a76848">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Accommodation.csv to Accommodation (1).csv
# Saving Activities.csv to Activities (1).csv

# %%
df_left = pd.read_csv('Accommodation.csv', header = 0, index_col= None)
df_right = pd.read_csv('Activities.csv', header = 0, index_col= None)

print(df_left)
print(df_right)

Ireland = pd.merge(left=df_left, right=df_right, how='inner', left_on='Name', right_on='Name')

print(Ireland)
# Out:
#                                   Name  \
# 0                         Bramble Rock
# 1                        The Davenport
# 2                       Townsend House
# 3                         River's Edge
# 4     Amber Springs Hotel & Health Spa
# ...                                ...
# 2768        The Red Door Country House
# 2769                   The Savoy Hotel
# 2770                  Dunmanus Cottage
# 2771           Travelodge Cork Airport
# 2772             Victoria Towers Hotel
#
#                                                Url         Telephone  \
# 0                       http://www.bramblerock.com   +353(0)40445075
# 1     http://www.instagram.com/thedavenportdublin/   +353(0)16073500
# 2          http://www.townsendhouse-guesthouse.com  +353(0)579121276
# 3                         http://www.riversedge.ie        3.5367E+11
# 4                     https://www.ambersprings.ie/  +353(0)539484000
# ...                                            ...               ...
# ...

# %%
Ireland.head()
# Out:
#                                      Name  \
# 0                         Ballyhass Lakes
# 1                              Greenacres
# 2            Carlingford Adventure Centre
# 3  Great National Ballykisteen Golf Hotel
# 4                  Monart Destination Spa
#
#                                  Url_x       Telephone_x  Longitude_x  \
# 0         http://www.ballyhasslakes.ie    +353(0)2227773    -8.790095
# 1   http://www.greenacresrathcoole.com   +353(0)14580732    -6.499315
# 2  http://www.carlingfordadventure.com  +353(0)429373100    -6.186241
# 3     http://www.ballykisteenhotel.com    +353(0)6233333    -8.216777
# 4                 http://www.monart.ie  +353(0)539238999    -6.611292
#
#    Latitude_x AddressRegion_x AddressLocality_x     AddressCountry_x  \
# 0   52.170583            Cork        Cecilstown  Republic of Ireland
# 1   53.257096          Dublin           Newtown  Republic of Ireland
# 2   54.040061           Louth       Carlingford  Republic of Ireland
# ...
