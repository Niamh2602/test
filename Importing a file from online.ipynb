# %% [markdown]
# <a href="https://colab.research.google.com/github/Niamh2602/test/blob/main/Importing%20a%20file%20from%20online.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('https://raw.githubusercontent.com/cianucdpa/GitRepo/master/brics.csv')
# Out:
#   label       country    capital    area  population
# 0    BR        Brazil   Brasilia   8.516      200.40
# 1    RU        Russia     Moscow  17.100      143.50
# 2    IN         India  New Delhi   3.286     1252.00
# 3    CH         China    Beijing   9.597     1357.00
# 4    SA  South Africa   Pretoria   1.221       52.98

# %%
pd.read_csv('https://github.com/Niamh2602/NiamhProject/Accommodation.csv')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-5-a4e31996e806> in <module>()
# ----> 1 pd.read_csv('https://github.com/Niamh2602/NiamhProject/Accommodation.csv')
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b1ebefb-3c60-4bbe-892a-56d8e1a18fd4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b1ebefb-3c60-4bbe-892a-56d8e1a18fd4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Accommodation.csv to Accommodation.csv

# %%
pip install pandas

# %%
pd.read_csv('Accommodation.csv')
# Out:
#                                   Name  \
# 0                         Bramble Rock
# 1                        The Davenport
# 2                       Townsend House
# 3                         River's Edge
# 4     Amber Springs Hotel & Health Spa
# ...                                ...
# 2768        The Red Door Country House
# 2769                   The Savoy Hotel
# 2770                  Dunmanus Cottage
# 2771           Travelodge Cork Airport
# 2772             Victoria Towers Hotel
#
#                                                Url         Telephone  \
# 0                       http://www.bramblerock.com   +353(0)40445075
# 1     http://www.instagram.com/thedavenportdublin/   +353(0)16073500
# 2          http://www.townsendhouse-guesthouse.com  +353(0)579121276
# 3                         http://www.riversedge.ie        3.5367E+11
# 4                     https://www.ambersprings.ie/  +353(0)539484000
# ...                                            ...               ...
# ...
