# %% [markdown]
# <a href="https://colab.research.google.com/github/Niamh2602/test/blob/main/Project_test_(Accommodation%20only).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files
import io
import pandas as pd
import folium
import gc


data = files.upload()
# Out:
#      <input type="file" id="files-f23d77b2-8513-43a9-aac7-4574b23ba069" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f23d77b2-8513-43a9-aac7-4574b23ba069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Accommodation.csv to Accommodation.csv
# Saving Activities.csv to Activities.csv

# %%
Accommodation = pd.read_csv('Accommodation.csv', header = 0, index_col= None)
Activities = pd.read_csv('Activities.csv', header = 0, index_col= None)

# %%
Accommodation.head()
# Out:
#                                Name  \
# 0                      Bramble Rock
# 1                     The Davenport
# 2                    Townsend House
# 3                      River's Edge
# 4  Amber Springs Hotel & Health Spa
#
#                                             Url         Telephone  Longitude  \
# 0                    http://www.bramblerock.com   +353(0)40445075  -6.291733
# 1  http://www.instagram.com/thedavenportdublin/   +353(0)16073500  -6.250031
# 2       http://www.townsendhouse-guesthouse.com  +353(0)579121276  -7.909500
# 3                      http://www.riversedge.ie        3.5367E+11  -9.783882
# 4                  https://www.ambersprings.ie/  +353(0)539484000  -6.290339
#
#     Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  53.009756       Wicklow     Glendalough  Republic of Ireland
# 1  53.341665        Dublin     Dublin City  Republic of Ireland
# 2  53.098816        Offaly            Birr  Republic of Ireland
# ...

# %%
Accommodation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2773 entries, 0 to 2772
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             2773 non-null   object
#  1   Url              2591 non-null   object
#  2   Telephone        2768 non-null   object
#  3   Longitude        2773 non-null   float64
#  4   Latitude         2773 non-null   float64
#  5   AddressRegion    2773 non-null   object
#  6   AddressLocality  2631 non-null   object
#  7   AddressCountry   2773 non-null   object
#  8   Tags             2773 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 195.1+ KB

# %%
Accommodation.isnull().sum()
# Out:
# Name                 0
# Url                182
# Telephone            5
# Longitude            0
# Latitude             0
# AddressRegion        0
# AddressLocality    142
# AddressCountry       0
# Tags                 0
# dtype: int64

# %%
Activities.head()
# Out:
#                                 Name  \
# 0  The Restaurant at the Abbey Hotel
# 1                      Café Nutshell
# 2       Guided Walking Tour of Sligo
# 3                The Italian Kitchen
# 4            Brasserie on the Corner
#
#                                            Url        Telephone  Longitude  \
# 0  http://www.abbeyhotel.ie/food-and-wine.html     353907000000  -8.193639
# 1       https://www.facebook.com/cafenutshell/      35351422777  -6.944210
# 2                                          NaN              NaN  -8.477043
# 3                  http://theitaliankitchen.ie  +353(0)18711255  -6.218041
# 4                  https://brasseriegalway.com      35391530333  -9.052901
#
#     Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  53.624876     Roscommon             NaN              Ireland
# 1  52.395136       Wexford        New Ross  Republic of Ireland
# 2  54.268771         Sligo      Sligo Town  Republic of Ireland
# ...

# %%
Activities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6318 entries, 0 to 6317
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             6318 non-null   object
#  1   Url              5893 non-null   object
#  2   Telephone        5743 non-null   object
#  3   Longitude        6318 non-null   float64
#  4   Latitude         6318 non-null   float64
#  5   AddressRegion    6314 non-null   object
#  6   AddressLocality  5375 non-null   object
#  7   AddressCountry   6318 non-null   object
#  8   Tags             6236 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 444.4+ KB

# %%
Activities.isnull().sum()
# Out:
# Name                 0
# Url                425
# Telephone          575
# Longitude            0
# Latitude             0
# AddressRegion        4
# AddressLocality    943
# AddressCountry       0
# Tags                82
# dtype: int64

# %%
Accommodation['File_Type'] = "Accom."
print(Accommodation)
# Out:
#                                   Name  \
# 0                         Bramble Rock
# 1                        The Davenport
# 2                       Townsend House
# 3                         River's Edge
# 4     Amber Springs Hotel & Health Spa
# ...                                ...
# 2768        The Red Door Country House
# 2769                   The Savoy Hotel
# 2770                  Dunmanus Cottage
# 2771           Travelodge Cork Airport
# 2772             Victoria Towers Hotel
#
#                                                Url         Telephone  \
# 0                       http://www.bramblerock.com   +353(0)40445075
# 1     http://www.instagram.com/thedavenportdublin/   +353(0)16073500
# 2          http://www.townsendhouse-guesthouse.com  +353(0)579121276
# 3                         http://www.riversedge.ie        3.5367E+11
# 4                     https://www.ambersprings.ie/  +353(0)539484000
# ...                                            ...               ...
# ...

# %%
Activities['File_Type'] = "Act."
print(Activities)
# Out:
#                                         Name  \
# 0          The Restaurant at the Abbey Hotel
# 1                              Café Nutshell
# 2               Guided Walking Tour of Sligo
# 3                        The Italian Kitchen
# 4                    Brasserie on the Corner
# ...                                      ...
# 6313                          The Marine Bar
# 6314                 The West End Cliff Walk
# 6315  The Workhouse Famine & Heritage Centre
# 6316   Walking Hiking Tours - JAQUIER Lilian
# 6317                Youghal Clock Gate Tower
#
#                                                     Url         Telephone  \
# 0           http://www.abbeyhotel.ie/food-and-wine.html      353907000000
# 1                https://www.facebook.com/cafenutshell/       35351422777
# 2                                                   NaN               NaN
# 3                           http://theitaliankitchen.ie   +353(0)18711255
# ...

# %%
pd.concat([Accommodation,Activities])
# Out:
#                                         Name  \
# 0                               Bramble Rock
# 1                              The Davenport
# 2                             Townsend House
# 3                               River's Edge
# 4           Amber Springs Hotel & Health Spa
# ...                                      ...
# 6313                          The Marine Bar
# 6314                 The West End Cliff Walk
# 6315  The Workhouse Famine & Heritage Centre
# 6316   Walking Hiking Tours - JAQUIER Lilian
# 6317                Youghal Clock Gate Tower
#
#                                                     Url         Telephone  \
# 0                            http://www.bramblerock.com   +353(0)40445075
# 1          http://www.instagram.com/thedavenportdublin/   +353(0)16073500
# 2               http://www.townsendhouse-guesthouse.com  +353(0)579121276
# 3                              http://www.riversedge.ie        3.5367E+11
# ...

# %%
Ireland = pd.concat([Accommodation, Activities], axis = 0)

# %%
Ireland.head()
# Out:
#                                Name  \
# 0                      Bramble Rock
# 1                     The Davenport
# 2                    Townsend House
# 3                      River's Edge
# 4  Amber Springs Hotel & Health Spa
#
#                                             Url         Telephone  Longitude  \
# 0                    http://www.bramblerock.com   +353(0)40445075  -6.291733
# 1  http://www.instagram.com/thedavenportdublin/   +353(0)16073500  -6.250031
# 2       http://www.townsendhouse-guesthouse.com  +353(0)579121276  -7.909500
# 3                      http://www.riversedge.ie        3.5367E+11  -9.783882
# 4                  https://www.ambersprings.ie/  +353(0)539484000  -6.290339
#
#     Latitude AddressRegion AddressLocality       AddressCountry  \
# 0  53.009756       Wicklow     Glendalough  Republic of Ireland
# 1  53.341665        Dublin     Dublin City  Republic of Ireland
# 2  53.098816        Offaly            Birr  Republic of Ireland
# ...

# %%
Ireland.columns = Ireland.columns.str.replace("AddressRegion" , "County")
Ireland.head()
# Out:
#                                Name  \
# 0                      Bramble Rock
# 1                     The Davenport
# 2                    Townsend House
# 3                      River's Edge
# 4  Amber Springs Hotel & Health Spa
#
#                                             Url         Telephone  Longitude  \
# 0                    http://www.bramblerock.com   +353(0)40445075  -6.291733
# 1  http://www.instagram.com/thedavenportdublin/   +353(0)16073500  -6.250031
# 2       http://www.townsendhouse-guesthouse.com  +353(0)579121276  -7.909500
# 3                      http://www.riversedge.ie        3.5367E+11  -9.783882
# 4                  https://www.ambersprings.ie/  +353(0)539484000  -6.290339
#
#     Latitude   County AddressLocality       AddressCountry  \
# 0  53.009756  Wicklow     Glendalough  Republic of Ireland
# 1  53.341665   Dublin     Dublin City  Republic of Ireland
# 2  53.098816   Offaly            Birr  Republic of Ireland
# ...

# %%
Ireland.drop(['Url', 'Telephone','AddressLocality', 'AddressCountry'], axis=1)
Ire = Ireland.drop(['Url', 'Telephone','AddressLocality', 'AddressCountry'], axis=1)
print(Ire)
# Out:
#                                         Name  Longitude   Latitude     County  \
# 0                               Bramble Rock  -6.291733  53.009756    Wicklow
# 1                              The Davenport  -6.250031  53.341665     Dublin
# 2                             Townsend House  -7.909500  53.098816     Offaly
# 3                               River's Edge  -9.783882  52.106485      Kerry
# 4           Amber Springs Hotel & Health Spa  -6.290339  52.668124    Wexford
# ...                                      ...        ...        ...        ...
# 6313                          The Marine Bar  -7.659723  52.041345  Waterford
# 6314                 The West End Cliff Walk  -8.274541  54.479625    Donegal
# 6315  The Workhouse Famine & Heritage Centre  -7.976993  55.179878    Donegal
# 6316   Walking Hiking Tours - JAQUIER Lilian -10.021117  53.489293     Galway
# 6317                Youghal Clock Gate Tower  -7.846767  51.952759       Cork
#
# ...

# %%
Ire.isnull().sum()
# Out:
# Name          0
# Longitude     0
# Latitude      0
# County        4
# Tags         82
# File_Type     0
# dtype: int64

# %%
Ire[Ire['County'].isnull()]
# Out:
#                         Name  Longitude   Latitude County  \
# 291             The Elm Tree  -8.304398  51.911999    NaN
# 1687  Knoxs Pub & Restaurant  -8.982425  52.844943    NaN
# 2229       The Roundwood Inn  -6.224734  53.064770    NaN
# 3068   Toddies at the Bulman  -8.499729  51.700103    NaN
#
#                                                    Tags File_Type
# 291   Covid Safety Charter,Food and Drink,Restaurant...      Act.
# 1687             Food and Drink,Restaurant,Pubs and Bar      Act.
# 2229       Food and Drink,Restaurant,Seafood,Vegetarian      Act.
# 3068                          Food and Drink,Restaurant      Act.

# %%
Ire.loc[Ire["Name"] == "The Elm Tree" , "County"] = 'Cork'
Ire.loc[Ire["Name"] == "Knoxs Pub & Restaurant" , "County"] = 'Clare'
Ire.loc[Ire["Name"] == "The Roundwood Inn" , "County"] = 'Wicklow'
Ire.loc[Ire["Name"] == "Toddies at the Bulman" , "County"] = 'Cork'

# %%
Ire[Ire['County'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Longitude, Latitude, County, Tags, File_Type]
# Index: []

# %%
Ire[Ire['Tags'].isnull()]
# Out:
#                                             Name  Longitude   Latitude  \
# 47                                  Staigue Fort -10.038945  51.780516
# 80                            The Ha'Penny Laugh  -6.263344  53.345871
# 161                           Haroldstown Dolmen  -6.663829  52.845101
# 215                      Ballynamona Court Cairn  -7.581712  52.003606
# 237                 Explore Louth Heritage Trail  -6.405957  53.997945
# ...                                          ...        ...        ...
# 5752                          Arthur's Quay Park  -8.626228  52.665374
# 5825                                 Mullaghmast  -6.848484  53.006619
# 5863  Westport Skate Park & Multi-use Games Area  -9.529272  53.795305
# 5911                          Dean Crowe Theatre  -7.943734  53.421923
# 5980                           The Pollock Holes  -9.664980  52.682283
#
#          County Tags File_Type
# 47        Kerry  NaN      Act.
# 80       Dublin  NaN      Act.
# ...

# %%
Ire.dropna(axis = 0, how = 'any', inplace = True)

# %%
Ire[Ire['Tags'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Name, Longitude, Latitude, County, Tags, File_Type]
# Index: []

# %%
print(Ire)
# Out:
#                                         Name  Longitude   Latitude     County  \
# 0                               Bramble Rock  -6.291733  53.009756    Wicklow
# 1                              The Davenport  -6.250031  53.341665     Dublin
# 2                             Townsend House  -7.909500  53.098816     Offaly
# 3                               River's Edge  -9.783882  52.106485      Kerry
# 4           Amber Springs Hotel & Health Spa  -6.290339  52.668124    Wexford
# ...                                      ...        ...        ...        ...
# 6313                          The Marine Bar  -7.659723  52.041345  Waterford
# 6314                 The West End Cliff Walk  -8.274541  54.479625    Donegal
# 6315  The Workhouse Famine & Heritage Centre  -7.976993  55.179878    Donegal
# 6316   Walking Hiking Tours - JAQUIER Lilian -10.021117  53.489293     Galway
# 6317                Youghal Clock Gate Tower  -7.846767  51.952759       Cork
#
# ...

# %%
#multiple listed categories are in single row which is not good and that effect our analysis try to correct them

# %%
Ire["Tags"].value_counts().head(30)
# Out:
# B&B,Covid Safety Charter                                                               450
# Hotel,Covid Safety Charter                                                             392
# Food and Drink,Restaurant                                                              330
# Food and Drink,Restaurant,Pubs and Bar                                                 309
# Activity Operator,Tour                                                                 306
# B&B                                                                                    288
# Hotel,Covid Safety Charter,Stay and Spend                                              287
# Walking                                                                                184
# Self Catering Accommodation                                                            178
# Craft,Shopping,Shopping Centres and Department Store,Food Shops                        163
# ...
